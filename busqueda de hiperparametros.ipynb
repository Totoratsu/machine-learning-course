# %% [markdown]
# # Taller de búsqueda de hiperparámetros
#
# En este taller vamos a explorar la búsqueda de hiperparámetros de manera automática.

# %% [markdown]
# ## Nixon Lizcano

# %%
import time
import numpy as np

from sklearn.datasets import load_breast_cancer
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
X, y = load_breast_cancer(return_X_y=True)

# %%
test_size=0.25
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

# %% [markdown]
# **Ejemplo 1:** encuentra los mejores hiperparámetros usando `GridSearchCV`

# %%
clf = DecisionTreeClassifier()

# define los valores que usarás en la búsqueda del
# hiperparametro C
param_grid = {
    "max_depth": (3, 6, 12, 18),
    "min_samples_leaf": (1, 2, 3),
    "criterion": ["gini", "entropy"]
}

# Utiliza GridSearchCV
gs = GridSearchCV(clf, param_grid)

t0 = time.time()
gs.fit(X_train, y_train)
print("Tiempo de búsqueda: {:.3f}s".format(time.time() - t0))
# Out:
# Tiempo de búsqueda: 0.472s

# %% [markdown]
# podemos ver que el atributo `cv_results_` nos entrega los resultados de toda la búsqueda.

# %%
dir(gs)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_refit_for_multimetric',
#  '_check_scorers_accept_sample_weight',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_format_results',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_get_routed_params_for_fit',
#  '_get_scorers',
#  '_html_repr',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_run_search',
#  '_select_best_index',
#  '_sk_visual_block_',
#  '_validate_params',
#  'best_estimator_',
#  'best_index_',
#  'best_params_',
#  'best_score_',
#  'classes_',
#  'cv',
#  'cv_results_',
#  'decision_function',
#  'error_score',
#  'estimator',
#  'fit',
#  'get_metadata_routing',
#  'get_params',
#  'inverse_transform',
#  'multimetric_',
#  'n_features_in_',
#  'n_jobs',
#  'n_splits_',
#  'param_grid',
#  'pre_dispatch',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'refit',
#  'refit_time_',
#  'return_train_score',
#  'score',
#  'score_samples',
#  'scorer_',
#  'scoring',
#  'set_params',
#  'transform',
#  'verbose']

# %%
gs.cv_results_
# Out:
# {'mean_fit_time': array([0.0028367 , 0.002701  , 0.00253406, 0.00354619, 0.00346074,
#         0.00338445, 0.00354981, 0.0033524 , 0.00330281, 0.0035584 ,
#         0.00337086, 0.00329361, 0.00306373, 0.00304418, 0.00302939,
#         0.00387735, 0.00381784, 0.00369658, 0.00380235, 0.00380359,
#         0.00368099, 0.00387335, 0.00373197, 0.00368438]),
#  'std_fit_time': array([2.42981777e-04, 1.76519255e-04, 8.24111468e-05, 3.51508441e-04,
#         3.23666849e-04, 2.39734670e-04, 3.92576763e-04, 2.48985672e-04,
#         2.45241203e-04, 3.87118390e-04, 2.20097289e-04, 2.33660941e-04,
#         1.73449475e-05, 1.99021114e-05, 1.81789437e-05, 1.75769796e-04,
#         1.61475495e-04, 5.70964662e-05, 7.57963224e-05, 1.45396446e-04,
#         4.89833625e-05, 1.86793189e-04, 3.81407137e-05, 3.56945659e-05]),
#  'mean_score_time': array([0.00040026, 0.00034037, 0.0003015 , 0.00029721, 0.00031452,
#         0.00033808, 0.00029221, 0.0002923 , 0.00029559, 0.00030036,
#         0.00029483, 0.00029073, 0.00029078, 0.0002954 , 0.00029683,
#         0.00030222, 0.0002914 , 0.00030246, 0.00032477, 0.00029659,
#         0.00029454, 0.0002986 , 0.0002996 , 0.00029325]),
#  'std_score_time': array([9.24256798e-05, 5.79694759e-05, 1.48123766e-05, 1.05827774e-05,
#         1.71418813e-05, 5.16828572e-05, 8.35567836e-06, 5.30555002e-06,
#         5.11439807e-06, 9.08797083e-06, 9.05563856e-06, 6.87472852e-06,
#         6.67503898e-06, 8.62007640e-06, 1.28595830e-05, 1.12997328e-05,
#         6.08112281e-06, 1.19272215e-05, 2.24064761e-05, 1.41813968e-05,
#         9.86442285e-06, 9.73098355e-06, 9.65356797e-06, 9.86027300e-06]),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_max_depth': masked_array(data=[3, 3, 3, 6, 6, 6, 12, 12, 12, 18, 18, 18, 3, 3, 3, 6,
#                     6, 6, 12, 12, 12, 18, 18, 18],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_min_samples_leaf': masked_array(data=[1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3,
#                     1, 2, 3, 1, 2, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'params': [{'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 3},
#   {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 1},
#   {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 2},
#   {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 3},
#   {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1},
#   {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 2},
#   {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 3},
#   {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1},
#   {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2},
#   {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3},
#   {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 1},
#   {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 2},
#   {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 3},
#   {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 1},
#   {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 2},
#   {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 3}],
#  'split0_test_score': array([0.96511628, 0.96511628, 0.96511628, 0.95348837, 0.95348837,
#         0.95348837, 0.96511628, 0.95348837, 0.95348837, 0.95348837,
#         0.95348837, 0.95348837, 0.95348837, 0.95348837, 0.95348837,
#         0.88372093, 0.90697674, 0.90697674, 0.90697674, 0.90697674,
#         0.94186047, 0.95348837, 0.90697674, 0.94186047]),
#  'split1_test_score': array([0.91764706, 0.91764706, 0.91764706, 0.90588235, 0.87058824,
#         0.91764706, 0.89411765, 0.90588235, 0.91764706, 0.92941176,
#         0.88235294, 0.90588235, 0.91764706, 0.91764706, 0.91764706,
#         0.90588235, 0.89411765, 0.91764706, 0.90588235, 0.88235294,
#         0.91764706, 0.91764706, 0.90588235, 0.91764706]),
#  'split2_test_score': array([0.96470588, 0.96470588, 0.96470588, 0.94117647, 0.94117647,
#         0.91764706, 0.94117647, 0.92941176, 0.92941176, 0.95294118,
#         0.94117647, 0.94117647, 0.94117647, 0.95294118, 0.94117647,
#         0.95294118, 0.95294118, 0.96470588, 0.96470588, 0.96470588,
#         0.95294118, 0.96470588, 0.95294118, 0.95294118]),
#  'split3_test_score': array([0.89411765, 0.89411765, 0.89411765, 0.87058824, 0.85882353,
#         0.85882353, 0.85882353, 0.85882353, 0.85882353, 0.88235294,
#         0.85882353, 0.87058824, 0.88235294, 0.91764706, 0.90588235,
#         0.92941176, 0.94117647, 0.92941176, 0.91764706, 0.92941176,
#         0.92941176, 0.91764706, 0.92941176, 0.94117647]),
#  'split4_test_score': array([0.89411765, 0.91764706, 0.91764706, 0.94117647, 0.92941176,
#         0.97647059, 0.90588235, 0.90588235, 0.94117647, 0.91764706,
#         0.97647059, 0.97647059, 0.91764706, 0.91764706, 0.91764706,
#         0.94117647, 0.91764706, 0.91764706, 0.92941176, 0.90588235,
#         0.92941176, 0.94117647, 0.92941176, 0.92941176]),
#  'mean_test_score': array([0.9271409 , 0.93184679, 0.93184679, 0.92246238, 0.91069767,
#         0.92481532, 0.91302326, 0.91069767, 0.92010944, 0.92716826,
#         0.92246238, 0.9295212 , 0.92246238, 0.93187415, 0.92716826,
#         0.92262654, 0.92257182, 0.9272777 , 0.92492476, 0.91786594,
#         0.93425445, 0.93893297, 0.92492476, 0.93660739]),
#  'std_test_score': array([0.03201394, 0.02833137, 0.02833137, 0.03042654, 0.03849652,
#         0.03987003, 0.03701976, 0.03136419, 0.03288322, 0.02631004,
#         0.04447108, 0.03727306, 0.02436379, 0.01742541, 0.01745494,
#         0.02491237, 0.02165886, 0.02001525, 0.02163507, 0.02775118,
#         0.01208101, 0.0189067 , 0.01737775, 0.01205434]),
#  'rank_test_score': array([11,  5,  5, 17, 24, 14, 22, 23, 20,  9, 19,  7, 17,  4,  9, 15, 16,
#          8, 12, 21,  3,  1, 12,  2], dtype=int32)}

# %% [markdown]
# Lo más importante es extraer los hiperparámetros del modelo que mejor error en de validación sacaron

# %%
gs.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 1}

# %% [markdown]
# También es posible el mejor resultado en la métrica usada

# %%
gs.best_score_
# Out:
# np.float64(0.9389329685362517)

# %% [markdown]
# Finalmente, es posible extraer directamente un estimador que que ha sido creado con los mejores hiperparámetros.

# %%
gs.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=18)

# %% [markdown]
# **Ejemplo 2:** la clase `RandomizedSearchCV` se puede usar casi de la misma manera, solo que esta vez se debe escoger un número de combinaciones a evaluar; las cuales se escogeran de manera aleatoria.

# %%
clf = DecisionTreeClassifier()

# define los valores que usarás en la búsqueda del
# hiperparametro C
param_dist = {
    "max_depth": (3, 6, 12, 18),
    "min_samples_leaf": (1, 2, 3),
    "criterion": ["gini", "entropy"]
}

# Utiliza RandomizedSearchCV
rs = RandomizedSearchCV(clf, param_dist)

t0 = time.time()
rs.fit(X_train, y_train)
print("Tiempo de búsqueda: {:.3f}s".format(time.time() - t0))
# Out:
# Tiempo de búsqueda: 0.200s

# %%
rs.best_score_
# Out:
# np.float64(0.9366073871409029)

# %% [markdown]
# Podemos ver que aunque se demoró mucho menos, el resultado no es tan bueno.

# %% [markdown]
# ## HyperOPt

# %%
# %pip install hyperopt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from hyperopt import hp, fmin, tpe, space_eval, STATUS_OK
from sklearn.model_selection import cross_val_score

# %%
def funcion_objetivo(params):
    clf = DecisionTreeClassifier(
        max_depth=int(params['max_depth']),
        min_samples_leaf=int(params['min_samples_leaf']),
        criterion=params['criterion']
    )

    scores = cross_val_score(clf, X_train, y_train,
                             cv=5,
                             scoring='accuracy')

    loss = 1.0 - np.mean(scores)
    return {'loss': loss, 'status': STATUS_OK}

params = {
    "max_depth": hp.choice("max_depth", (3, 6, 12, 18)),
    "min_samples_leaf": hp.choice("min_samples_leaf", (1, 2, 3)),
    "criterion": hp.choice("criterion", ["gini", "entropy"])
}

best = fmin(funcion_objetivo, params, algo=tpe.suggest, max_evals=100)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 43.03trial/s, best loss: 0.061039671682626584]

# %%
best
# Out:
# {'criterion': np.int64(1),
#  'max_depth': np.int64(3),
#  'min_samples_leaf': np.int64(2)}
