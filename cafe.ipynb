# %%
# %pip install -r requirements.txt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
#import shap

# %%
excel_calidad = pd.read_excel(
    'CC_FT_17_Formato_de_Control_de_Calidad_Café_de_Trillado.xlsx',
    sheet_name = ['CONTROL CALIDAD CAFE TRILLADO J' , 'Sheet2'],
    skiprows=5,
    skipfooter=4
)

excel_calidad['CONTROL CALIDAD CAFE TRILLADO J'].columns = excel_calidad['CONTROL CALIDAD CAFE TRILLADO J'].columns.str.strip()
excel_calidad['Sheet2'].columns = excel_calidad['Sheet2'].columns.str.strip()
df_calidad = pd.concat(excel_calidad.values(), ignore_index=True)

df_calidad = df_calidad[[
    'LOTE', 'DENOMINACIÓN/     MARCA', 'CANTIDAD', '%H', 'MALLAS',
    'NOTAS DE CATACIÓN', 'PUNTAJE'
]]
df_calidad.dropna(subset=['LOTE'], inplace=True)

df_calidad
# Out:
#             LOTE DENOMINACIÓN/     MARCA  CANTIDAD    %H MALLAS  \
# 2      01-190722            Madre Laura     765.00  10.9     14
# 3      09-190722           Tabi Natural     204.00  10.2     14
# 4      10-190722              Don Mario     165.00  10.7     14
# 5    07-19-07-22              Don Felix       0.45  10.5     14
# 6      01-291022            Madre Laura     105.00  10.7     14
# ..           ...                     ...       ...   ...    ...
# 120    01-271023            Madre Laura      20.00  10.5     14
# 121    01-100124            Madre Laura      20.00  10.4     14
# 122    01-020424            Madre Laura      20.00  10.5     14
# 123    01-200624            Madre Laura      14.00  10.8     14
# 124    01-180724            Madre Laura      20.00  10.2     14
#
#                                      NOTAS DE CATACIÓN PUNTAJE
# 2    Chocolate negro, toque frutal, cuerpo medio, a...      84
# 3    Frutas maduras, nibs de cacao, acidez brillant...      85
# 4    Panela, durazno, miel, acidez brillante citric...    84.5
# 5    Moras maduras, chocolate negro, acidez media c...    84.5
# 6    Chocolate negro, toque frutal, cuerpo medio, a...      84
# ..                                                 ...     ...
# 120  Chocolate negro, toque frutal, cuerpo medio, a...      84
# 121  Chocolate negro, toque frutal, cuerpo medio, a...      84
# 122  Chocolate negro, toque frutal, cuerpo medio, a...      84
# 123  Chocolate negro, toque frutal, cuerpo medio, a...      84
# 124  Chocolate negro, toque frutal, cuerpo medio, a...      84
#
# [108 rows x 7 columns]

# %%
# Out:
# array([14, 16, 15], dtype=object)
